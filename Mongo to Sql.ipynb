# %%
# pip install pandas mysql-connector-python

# %% [markdown]
# # ETL Process for Amazon Dataset

# %% [markdown]
# ## Extract - Extracting data from MongoDB(Semi-structured)

# %%
#Import neccessary libraries
import pymongo
import pandas as pd
import mysql.connector

# %%
#connect to MongoDB server.
client = pymongo.MongoClient('mongodb://localhost:27017/', serverSelectionTimeoutMS=50000)
database_name = 'DAP_Project'
collection_list = client.list_database_names()
collection_list
# Out:
# ['DAP_Project', 'admin', 'config', 'local']

# %%
# Check if database name exist - 
    #if yes - then it will access collection and load data in Amazon_data
    #if no - it will raise ValueError
    
if database_name in collection_list:
    db = client[database_name]
    Amazon_collection = db['Amazon']
    Amazon_data = Amazon_collection.find()
else:
    raise ValueError(f"Database {database_name} not found in the collection list")

# %%
#convert data into pandas DataFrame
amazon_df = pd.DataFrame(list(Amazon_data))

# %%
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  ₹14,990
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   ₹9,499
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   ₹7,499
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   ₹5,899
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   ₹8,999
# ...                                                 ...      ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   ₹7,799
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  ₹17,499
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  ₹12,499
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   ₹5,699
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   ₹7,799
#
#                   rating         reviews availability
# 0          Previous page                     In stock
# 1          Previous page                     In stock
# 2     3.9 out of 5 stars   3,403 ratings     In stock
# 3     4.0 out of 5 stars  13,373 ratings     In stock
# 4     4.0 out of 5 stars  17,087 ratings     In stock
# ...                  ...             ...          ...
# 3205  3.9 out of 5 stars   4,825 ratings     In stock
# 3206  4.1 out of 5 stars  27,309 ratings     In stock
# 3207  4.0 out of 5 stars   1,295 ratings     In stock
# 3208  4.0 out of 5 stars  14,112 ratings     In stock
# 3209  3.9 out of 5 stars   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %% [markdown]
# ## Transform - Cleaning of data

# %%
amazon_df.shape
# Out:
# (3210, 6)

# %%
#checking record for reviews column for 0th index
amazon_df['reviews'][0]
# Out:
# ''

# %%
# Dataframe contains blank spaces so replace blank with none.

amazon_df['price'] = amazon_df['price'].replace('', None)
amazon_df['reviews'] = amazon_df['reviews'].replace('', None)
amazon_df['availability'] = amazon_df['availability'].replace('', None)

# %%
# Check if null values exists
amazon_df.isnull().sum()
# Out:
# _id               0
# title             0
# price             9
# rating            0
# reviews         164
# availability     40
# dtype: int64

# %%
amazon_df['price'] = amazon_df['price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0
# ...                                                 ...      ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
#
#                   rating         reviews availability
# 0          Previous page            None     In stock
# 1          Previous page            None     In stock
# 2     3.9 out of 5 stars   3,403 ratings     In stock
# 3     4.0 out of 5 stars  13,373 ratings     In stock
# 4     4.0 out of 5 stars  17,087 ratings     In stock
# ...                  ...             ...          ...
# 3205  3.9 out of 5 stars   4,825 ratings     In stock
# 3206  4.1 out of 5 stars  27,309 ratings     In stock
# 3207  4.0 out of 5 stars   1,295 ratings     In stock
# 3208  4.0 out of 5 stars  14,112 ratings     In stock
# 3209  3.9 out of 5 stars   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
#amazon_df['title'] = amazon_df['title'].str.replace('(\d+GB) RAM.*(\d+GB|\d+TB) Storage', '')
# Out:
# C:\Users\Begena\AppData\Local\Temp\ipykernel_13044\3363329258.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_df['title'] = amazon_df['title'].str.replace('(\d+GB) RAM.*(\d+GB|\d+TB) Storage', '')

# %%
#amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
#remove any leading or trailing white spaces from string values 
amazon_df = amazon_df.apply(lambda x: x.str.strip() if x.dtype == 'object' and x.name != '_id' else x)

# %%
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0
# ...                                                 ...      ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
#
#                   rating         reviews availability
# 0          Previous page            None     In stock
# 1          Previous page            None     In stock
# 2     3.9 out of 5 stars   3,403 ratings     In stock
# 3     4.0 out of 5 stars  13,373 ratings     In stock
# 4     4.0 out of 5 stars  17,087 ratings     In stock
# ...                  ...             ...          ...
# 3205  3.9 out of 5 stars   4,825 ratings     In stock
# 3206  4.1 out of 5 stars  27,309 ratings     In stock
# 3207  4.0 out of 5 stars   1,295 ratings     In stock
# 3208  4.0 out of 5 stars  14,112 ratings     In stock
# 3209  3.9 out of 5 stars   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
#amazon_df = amazon_df.reset_index(drop=True)

# %%
#amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0
# ...                                                 ...      ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
#
#                   rating         reviews availability
# 0          Previous page            None     In stock
# 1          Previous page            None     In stock
# 2     3.9 out of 5 stars   3,403 ratings     In stock
# 3     4.0 out of 5 stars  13,373 ratings     In stock
# 4     4.0 out of 5 stars  17,087 ratings     In stock
# ...                  ...             ...          ...
# 3205  3.9 out of 5 stars   4,825 ratings     In stock
# 3206  4.1 out of 5 stars  27,309 ratings     In stock
# 3207  4.0 out of 5 stars   1,295 ratings     In stock
# 3208  4.0 out of 5 stars  14,112 ratings     In stock
# 3209  3.9 out of 5 stars   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
#Fill null values in reviews column as 0 ratings
amazon_df['reviews'].fillna("0 ratings", inplace=True)

# %%
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0
# ...                                                 ...      ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
#
#                   rating         reviews availability
# 0          Previous page       0 ratings     In stock
# 1          Previous page       0 ratings     In stock
# 2     3.9 out of 5 stars   3,403 ratings     In stock
# 3     4.0 out of 5 stars  13,373 ratings     In stock
# 4     4.0 out of 5 stars  17,087 ratings     In stock
# ...                  ...             ...          ...
# 3205  3.9 out of 5 stars   4,825 ratings     In stock
# 3206  4.1 out of 5 stars  27,309 ratings     In stock
# 3207  4.0 out of 5 stars   1,295 ratings     In stock
# 3208  4.0 out of 5 stars  14,112 ratings     In stock
# 3209  3.9 out of 5 stars   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
# Find most frequently occurring rating as average
frequency_rating = amazon_df['rating'].mode()[0]
frequency_rating
# Out:
# '4.1 out of 5 stars'

# %%
# Identifying the garbage rating and replacing it with average ration i.e. '4.5 out of 5 starts'
amazon_df['rating'] = amazon_df['rating'].replace('Previous page', frequency_rating)
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0
# ...                                                 ...      ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0
#
#                   rating         reviews availability
# 0     4.1 out of 5 stars       0 ratings     In stock
# 1     4.1 out of 5 stars       0 ratings     In stock
# 2     3.9 out of 5 stars   3,403 ratings     In stock
# 3     4.0 out of 5 stars  13,373 ratings     In stock
# 4     4.0 out of 5 stars  17,087 ratings     In stock
# ...                  ...             ...          ...
# 3205  3.9 out of 5 stars   4,825 ratings     In stock
# 3206  4.1 out of 5 stars  27,309 ratings     In stock
# 3207  4.0 out of 5 stars   1,295 ratings     In stock
# 3208  4.0 out of 5 stars  14,112 ratings     In stock
# 3209  3.9 out of 5 stars   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
#Unique values for rating column
amazon_df['rating'].unique()
# Out:
# array(['4.1 out of 5 stars', '3.9 out of 5 stars', '4.0 out of 5 stars',
#        '4.5 out of 5 stars', '4.3 out of 5 stars', '3.2 out of 5 stars',
#        '4.9 out of 5 stars', '4.4 out of 5 stars', '4.2 out of 5 stars',
#        '3.4 out of 5 stars', '4.6 out of 5 stars', '3.6 out of 5 stars',
#        '4.7 out of 5 stars'], dtype=object)

# %%
# Extracting the 1st 3 characters of rating column to get rid of repetative string 'out of 5 stars' numeric value
amazon_df['rating'] = amazon_df['rating'].apply(lambda x: float(str(x[:3]))) 
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  rating  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0     4.1
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0     4.1
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0     3.9
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0     4.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0     4.0
# ...                                                 ...      ...     ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0     4.1
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0     4.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0     4.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
#
#              reviews availability
# 0          0 ratings     In stock
# 1          0 ratings     In stock
# 2      3,403 ratings     In stock
# 3     13,373 ratings     In stock
# 4     17,087 ratings     In stock
# ...              ...          ...
# 3205   4,825 ratings     In stock
# 3206  27,309 ratings     In stock
# 3207   1,295 ratings     In stock
# 3208  14,112 ratings     In stock
# 3209   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
#Convert reviews column in string format
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: str(x))
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  rating  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0     4.1
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0     4.1
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0     3.9
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0     4.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0     4.0
# ...                                                 ...      ...     ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0     4.1
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0     4.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0     4.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
#
#              reviews availability
# 0          0 ratings     In stock
# 1          0 ratings     In stock
# 2      3,403 ratings     In stock
# 3     13,373 ratings     In stock
# 4     17,087 ratings     In stock
# ...              ...          ...
# 3205   4,825 ratings     In stock
# 3206  27,309 ratings     In stock
# 3207   1,295 ratings     In stock
# 3208  14,112 ratings     In stock
# 3209   4,825 ratings     In stock
#
# [3210 rows x 6 columns]

# %%
# Delete ratings word and comma from reviews
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: x[:-7])
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: x.replace(",", ""))
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  rating  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0     4.1
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0     4.1
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0     3.9
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0     4.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0     4.0
# ...                                                 ...      ...     ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0     4.1
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0     4.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0     4.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
#
#      reviews availability
# 0         0      In stock
# 1         0      In stock
# 2      3403      In stock
# 3     13373      In stock
# 4     17087      In stock
# ...      ...          ...
# 3205   4825      In stock
# 3206  27309      In stock
# 3207   1295      In stock
# 3208  14112      In stock
# 3209   4825      In stock
#
# [3210 rows x 6 columns]

# %%
#Covert reviws in int format
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: int(x))
amazon_df
# Out:
#                            _id  \
# 0     6442a3c3c69d033f5ddcd984
# 1     6442a3c3c69d033f5ddcd985
# 2     6442a3c3c69d033f5ddcd986
# 3     6442a3c3c69d033f5ddcd987
# 4     6442a3c3c69d033f5ddcd988
# ...                        ...
# 3205  6450b1bfe484c3c96e518b6e
# 3206  6450b1bfe484c3c96e518b6f
# 3207  6450b1bfe484c3c96e518b70
# 3208  6450b1bfe484c3c96e518b71
# 3209  6450b1bfe484c3c96e518b72
#
#                                                   title    price  rating  \
# 0     Samsung Galaxy M14 5G (Berry Blue, 4GB, 128GB ...  14990.0     4.1
# 1        Redmi 12C (Matte Black, 4GB RAM, 64GB Storage)   9499.0     4.1
# 2     Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   7499.0     3.9
# 3     Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...   5899.0     4.0
# 4     Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) ...   8999.0     4.0
# ...                                                 ...      ...     ...
# 3205  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
# 3206  Samsung Galaxy M33 5G (Emerald Brown, 8GB, 128...  17499.0     4.1
# 3207  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  12499.0     4.0
# 3208  Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Seg...   5699.0     4.0
# 3209  Tecno Spark 9 (Sky Mirror, 4GB RAM,64GB Storag...   7799.0     3.9
#
#       reviews availability
# 0           0     In stock
# 1           0     In stock
# 2        3403     In stock
# 3       13373     In stock
# 4       17087     In stock
# ...       ...          ...
# 3205     4825     In stock
# 3206    27309     In stock
# 3207     1295     In stock
# 3208    14112     In stock
# 3209     4825     In stock
#
# [3210 rows x 6 columns]

# %% [markdown]
# ## Load - Loading the cleaned data in mysql (Structured)

# %%
# Install pymysql
# pip install pymysql

# %%
# Import necessary libraries
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# create database connection string
db_connection_str = 'mysql+pymysql://root:root@localhost:3306/dap_project'

# create sqlalchemy engine
engine = create_engine(db_connection_str)

# create database if it doesn't exist
with engine.connect() as con:
    con.execute('CREATE DATABASE IF NOT EXISTS dap_project')

# switch to database
with engine.connect() as con:
    con.execute('USE dap_project')

# load data to mysql table
amazon_df.to_sql(name='amazon_tb', con=engine, if_exists='replace', index=False)
# Out:
# 3210

# %%
# check the table
pd.read_sql('SHOW TABLES', engine)
# Out:
#   Tables_in_dap_project
# 0             amazon_tb
# 1           flipkart_tb
# 2             mobile_tb

# %% [markdown]
# #  ETL Process for Flipkart Dataset

# %% [markdown]
# ## Extract - Extracting data from MongoDB(Semi-structured)

# %%
# Check if database name exist - 
    #if yes - then it will access collection and load data in Amazon_data
    #if no - it will raise ValueError
    
if database_name in collection_list:
    db = client[database_name]
    Flipkart_collection = db['Flipkart']
    Flipkart_data = Flipkart_collection.find()
else:
    raise ValueError(f"Database {database_name} not found in the collection list")

# %%
# Convert data into pandas DataFrame
flipkart_df =pd.DataFrame(list(Flipkart_data))

# %%
flipkart_df
# Out:
#                            _id  \
# 0     6442e598c69d033f5ddcde3b
# 1     6442e598c69d033f5ddcde3c
# 2     6442e598c69d033f5ddcde3d
# 3     6442e598c69d033f5ddcde3e
# 4     6442e598c69d033f5ddcde3f
# ...                        ...
# 3592  6450bc3de484c3c96e518f16
# 3593  6450bc3de484c3c96e518f17
# 3594  6450bc3de484c3c96e518f18
# 3595  6450bc3de484c3c96e518f19
# 3596  6450bc3de484c3c96e518f1a
#
#                                                   title    price rating  \
# 0            REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   ₹9,999    4.3
# 1             POCO M4 5G (Cool Blue, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 2     SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...   ₹7,499    4.3
# 3           POCO M4 5G (Power Black, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 4          POCO M4 5G (Power Black, 128 GB)  (6 GB RAM)  ₹12,999    4.2
# ...                                                 ...      ...    ...
# 3592                   GREENBERRI VIRAT  (BLACK & BLUE)     ₹749    3.8
# 3593  Infinix HOT 12 Play (Horizon Blue, 64 GB)  (4 ...   ₹8,999    4.3
# 3594  Infinix HOT 12 Play (Racing Black, 64 GB)  (4 ...   ₹8,999    4.3
# 3595  Infinix HOT 12 Play (Daylight Green, 64 GB)  (...   ₹8,999    4.3
# 3596   OPPO A 78 5G (Glowing Black, 128 GB)  (8 GB RAM)  ₹18,497      4
#
#      camera_rating        rating_count
# 0                   2,14,807 Ratings &
# 1                     65,594 Ratings &
# 2                      9,071 Ratings &
# 3                     65,594 Ratings &
# 4                     33,797 Ratings &
# ...            ...                 ...
# 3592                     507 Ratings &
# 3593                1,15,557 Ratings &
# 3594                1,15,557 Ratings &
# 3595                1,15,557 Ratings &
# 3596                      30 Ratings &
#
# [3597 rows x 6 columns]

# %% [markdown]
# ## Transform - Cleaning of data

# %%
flipkart_df.shape
# Out:
# (3597, 6)

# %%
#Chcek null values - camera setting column have no values but here it is giving o null values because it contains b spaces.
flipkart_df.isnull().sum()
# Out:
# _id                 0
# title               0
# price               2
# rating             36
# camera_rating    3597
# rating_count       36
# dtype: int64

# %%
# Dataframe contains blank spaces so replace blank with none.
flipkart_df['price'] = flipkart_df['price'].replace('', None)
flipkart_df['rating'] = flipkart_df['rating'].replace('', None)
flipkart_df['camera_rating'] = flipkart_df['camera_rating'].replace('', None)
flipkart_df['rating_count'] = flipkart_df['rating_count'].replace('', None)

# %%
flipkart_df.isnull().sum()
# Out:
# _id                 0
# title               0
# price               2
# rating             36
# camera_rating    3597
# rating_count       36
# dtype: int64

# %%
#drop column camera_rating as it does not have any record.
flipkart_df = flipkart_df.drop(["camera_rating"], axis=1)

# %%
flipkart_df
# Out:
#                            _id  \
# 0     6442e598c69d033f5ddcde3b
# 1     6442e598c69d033f5ddcde3c
# 2     6442e598c69d033f5ddcde3d
# 3     6442e598c69d033f5ddcde3e
# 4     6442e598c69d033f5ddcde3f
# ...                        ...
# 3592  6450bc3de484c3c96e518f16
# 3593  6450bc3de484c3c96e518f17
# 3594  6450bc3de484c3c96e518f18
# 3595  6450bc3de484c3c96e518f19
# 3596  6450bc3de484c3c96e518f1a
#
#                                                   title    price rating  \
# 0            REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   ₹9,999    4.3
# 1             POCO M4 5G (Cool Blue, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 2     SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...   ₹7,499    4.3
# 3           POCO M4 5G (Power Black, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 4          POCO M4 5G (Power Black, 128 GB)  (6 GB RAM)  ₹12,999    4.2
# ...                                                 ...      ...    ...
# 3592                   GREENBERRI VIRAT  (BLACK & BLUE)     ₹749    3.8
# 3593  Infinix HOT 12 Play (Horizon Blue, 64 GB)  (4 ...   ₹8,999    4.3
# 3594  Infinix HOT 12 Play (Racing Black, 64 GB)  (4 ...   ₹8,999    4.3
# 3595  Infinix HOT 12 Play (Daylight Green, 64 GB)  (...   ₹8,999    4.3
# 3596   OPPO A 78 5G (Glowing Black, 128 GB)  (8 GB RAM)  ₹18,497      4
#
#             rating_count
# 0     2,14,807 Ratings &
# 1       65,594 Ratings &
# 2        9,071 Ratings &
# 3       65,594 Ratings &
# 4       33,797 Ratings &
# ...                  ...
# 3592       507 Ratings &
# 3593  1,15,557 Ratings &
# 3594  1,15,557 Ratings &
# 3595  1,15,557 Ratings &
# 3596        30 Ratings &
#
# [3597 rows x 5 columns]

# %%
flipkart_df.isnull().sum()
# Out:
# _id              0
# title            0
# price            2
# rating          36
# rating_count    36
# dtype: int64

# %%
# Fill null values with 0
flipkart_df.fillna(0, inplace=True)

# %%
flipkart_df.isnull().sum()
# Out:
# _id             0
# title           0
# price           0
# rating          0
# rating_count    0
# dtype: int64

# %%
#Cleaning rating_count colum
flipkart_df["rating_count"] = flipkart_df["rating_count"].str.rstrip('Ratings &')

# %%
flipkart_df
# Out:
#                            _id  \
# 0     6442e598c69d033f5ddcde3b
# 1     6442e598c69d033f5ddcde3c
# 2     6442e598c69d033f5ddcde3d
# 3     6442e598c69d033f5ddcde3e
# 4     6442e598c69d033f5ddcde3f
# ...                        ...
# 3592  6450bc3de484c3c96e518f16
# 3593  6450bc3de484c3c96e518f17
# 3594  6450bc3de484c3c96e518f18
# 3595  6450bc3de484c3c96e518f19
# 3596  6450bc3de484c3c96e518f1a
#
#                                                   title    price rating  \
# 0            REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   ₹9,999    4.3
# 1             POCO M4 5G (Cool Blue, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 2     SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...   ₹7,499    4.3
# 3           POCO M4 5G (Power Black, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 4          POCO M4 5G (Power Black, 128 GB)  (6 GB RAM)  ₹12,999    4.2
# ...                                                 ...      ...    ...
# 3592                   GREENBERRI VIRAT  (BLACK & BLUE)     ₹749    3.8
# 3593  Infinix HOT 12 Play (Horizon Blue, 64 GB)  (4 ...   ₹8,999    4.3
# 3594  Infinix HOT 12 Play (Racing Black, 64 GB)  (4 ...   ₹8,999    4.3
# 3595  Infinix HOT 12 Play (Daylight Green, 64 GB)  (...   ₹8,999    4.3
# 3596   OPPO A 78 5G (Glowing Black, 128 GB)  (8 GB RAM)  ₹18,497      4
#
#      rating_count
# 0        2,14,807
# 1          65,594
# 2           9,071
# 3          65,594
# 4          33,797
# ...           ...
# 3592          507
# 3593     1,15,557
# 3594     1,15,557
# 3595     1,15,557
# 3596           30
#
# [3597 rows x 5 columns]

# %%
flipkart_df['rating_count'] = flipkart_df['rating_count'].str.replace(',','').astype(float)

# %%
flipkart_df
# Out:
#                            _id  \
# 0     6442e598c69d033f5ddcde3b
# 1     6442e598c69d033f5ddcde3c
# 2     6442e598c69d033f5ddcde3d
# 3     6442e598c69d033f5ddcde3e
# 4     6442e598c69d033f5ddcde3f
# ...                        ...
# 3592  6450bc3de484c3c96e518f16
# 3593  6450bc3de484c3c96e518f17
# 3594  6450bc3de484c3c96e518f18
# 3595  6450bc3de484c3c96e518f19
# 3596  6450bc3de484c3c96e518f1a
#
#                                                   title    price rating  \
# 0            REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   ₹9,999    4.3
# 1             POCO M4 5G (Cool Blue, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 2     SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...   ₹7,499    4.3
# 3           POCO M4 5G (Power Black, 64 GB)  (4 GB RAM)  ₹10,999    4.2
# 4          POCO M4 5G (Power Black, 128 GB)  (6 GB RAM)  ₹12,999    4.2
# ...                                                 ...      ...    ...
# 3592                   GREENBERRI VIRAT  (BLACK & BLUE)     ₹749    3.8
# 3593  Infinix HOT 12 Play (Horizon Blue, 64 GB)  (4 ...   ₹8,999    4.3
# 3594  Infinix HOT 12 Play (Racing Black, 64 GB)  (4 ...   ₹8,999    4.3
# 3595  Infinix HOT 12 Play (Daylight Green, 64 GB)  (...   ₹8,999    4.3
# 3596   OPPO A 78 5G (Glowing Black, 128 GB)  (8 GB RAM)  ₹18,497      4
#
#       rating_count
# 0         214807.0
# 1          65594.0
# 2           9071.0
# 3          65594.0
# 4          33797.0
# ...            ...
# 3592         507.0
# 3593      115557.0
# 3594      115557.0
# 3595      115557.0
# 3596          30.0
#
# [3597 rows x 5 columns]

# %%
flipkart_df['price'] = flipkart_df['price'].str.replace('₹','').str.replace(',','').astype(float)

# %%
flipkart_df
# Out:
#                            _id  \
# 0     6442e598c69d033f5ddcde3b
# 1     6442e598c69d033f5ddcde3c
# 2     6442e598c69d033f5ddcde3d
# 3     6442e598c69d033f5ddcde3e
# 4     6442e598c69d033f5ddcde3f
# ...                        ...
# 3592  6450bc3de484c3c96e518f16
# 3593  6450bc3de484c3c96e518f17
# 3594  6450bc3de484c3c96e518f18
# 3595  6450bc3de484c3c96e518f19
# 3596  6450bc3de484c3c96e518f1a
#
#                                                   title    price rating  \
# 0            REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   9999.0    4.3
# 1             POCO M4 5G (Cool Blue, 64 GB)  (4 GB RAM)  10999.0    4.2
# 2     SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...   7499.0    4.3
# 3           POCO M4 5G (Power Black, 64 GB)  (4 GB RAM)  10999.0    4.2
# 4          POCO M4 5G (Power Black, 128 GB)  (6 GB RAM)  12999.0    4.2
# ...                                                 ...      ...    ...
# 3592                   GREENBERRI VIRAT  (BLACK & BLUE)    749.0    3.8
# 3593  Infinix HOT 12 Play (Horizon Blue, 64 GB)  (4 ...   8999.0    4.3
# 3594  Infinix HOT 12 Play (Racing Black, 64 GB)  (4 ...   8999.0    4.3
# 3595  Infinix HOT 12 Play (Daylight Green, 64 GB)  (...   8999.0    4.3
# 3596   OPPO A 78 5G (Glowing Black, 128 GB)  (8 GB RAM)  18497.0      4
#
#       rating_count
# 0         214807.0
# 1          65594.0
# 2           9071.0
# 3          65594.0
# 4          33797.0
# ...            ...
# 3592         507.0
# 3593      115557.0
# 3594      115557.0
# 3595      115557.0
# 3596          30.0
#
# [3597 rows x 5 columns]

# %% [markdown]
# ## Load - Loading the cleaned data in mysql (Structured)

# %%
# load data to mysql table
flipkart_df.to_sql(name='flipkart_tb', con=engine, if_exists='replace', index=False)
# Out:
# 3597

# %%
# check the table
pd.read_sql('SHOW TABLES', engine)
# Out:
#   Tables_in_dap_project
# 0             amazon_tb
# 1           flipkart_tb
# 2             mobile_tb

# %% [markdown]
# # ETL process for other Mobile_data

# %% [markdown]
# ## Extract - Extracting data from MongoDB(Semi-structured)

# %%
# Check if database name exist - 
    #if yes - then it will access collection and load data in Amazon_data
    #if no - it will raise ValueError
    
if database_name in collection_list:
    db = client[database_name]
    Mobile_collection = db['Mobile_data']
    Mobile_data = Mobile_collection.find()
else:
    raise ValueError(f"Database {database_name} not found in the collection list")

# %%
##convert data into pandas DataFrame
mobile_df = pd.DataFrame(list(Mobile_data))

# %%
mobile_df
# Out:
#                            _id        asin     brand  \
# 0     644b208e025de930036751ea  B0000SX2UC       NaN
# 1     644b208e025de930036751eb  B0009N5L7K  Motorola
# 2     644b208e025de930036751ec  B000SKTZ0S  Motorola
# 3     644b208e025de930036751ed  B001AO4OUC  Motorola
# 4     644b208e025de930036751ee  B001DCJAJG  Motorola
# ...                        ...         ...       ...
# 1435  64502fc0b43a387639203fa4  B07ZPKZSSC     Apple
# 1436  64502fc0b43a387639203fa5  B07ZQSGP53    Xiaomi
# 1437  64502fc0b43a387639203fa6  B081H6STQQ      Sony
# 1438  64502fc0b43a387639203fa7  B081TJFVCJ     Apple
# 1439  64502fc0b43a387639203fa8  B0825BB7SG   Samsung
#
#                                                   title  \
# 0     Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1                                   Motorola I265 phone
# 2     MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3                 Motorola i335 Cell Phone Boost Mobile
# 4         Motorola V365 no contract cellular phone AT&T
# ...                                                 ...
# 1435  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...
# 1436  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...
# 1437  Sony Xperia 1 Unlocked Smartphone and WH1000XM...
# 1438  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...
# 1439  Straight Talk Samsung Galaxy A10e Smartphone 5...
#
#                                                     url  \
# 0     https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1     https://www.amazon.com/Motorola-i265-I265-phon...
# 2     https://www.amazon.com/MOTOROLA-C168i-CINGULAR...
# 3     https://www.amazon.com/Motorola-i335-Phone-Boo...
# 4     https://www.amazon.com/Motorola-V365-contract-...
# ...                                                 ...
# 1435  https://www.amazon.com/Apple-iPhone-64GB-Fully...
# 1436  https://www.amazon.com/Xiaomi-Display-Snapdrag...
# 1437  https://www.amazon.com/Sony-Smartphone-WH1000X...
# 1438  https://www.amazon.com/Apple-iPhone-64GB-Gray-...
# 1439  https://www.amazon.com/Straight-Samsung-Galaxy...
#
#                                                   image  rating  \
# 0     https://m.media-amazon.com/images/I/2143EBQ210...     3.0
# 1     https://m.media-amazon.com/images/I/419WBAVDAR...     3.0
# 2     https://m.media-amazon.com/images/I/71b+q3ydkI...     2.7
# 3     https://m.media-amazon.com/images/I/710UO8gdT+...     3.3
# 4     https://m.media-amazon.com/images/I/61LYNCVrrK...     3.1
# ...                                                 ...     ...
# 1435  https://m.media-amazon.com/images/I/41wDuEW9iZ...     1.0
# 1436  https://m.media-amazon.com/images/I/41foh4FKHE...     4.6
# 1437  https://m.media-amazon.com/images/I/51zZTAXZTP...     4.5
# 1438  https://m.media-amazon.com/images/I/71yMgOenT5...     5.0
# 1439  https://m.media-amazon.com/images/I/81+3SWSAhD...     5.0
#
#                                               reviewUrl  totalReviews   price  \
# 0     https://www.amazon.com/product-reviews/B0000SX2UC            14    0.00
# 1     https://www.amazon.com/product-reviews/B0009N5L7K             7   49.95
# 2     https://www.amazon.com/product-reviews/B000SKTZ0S            22   99.99
# 3     https://www.amazon.com/product-reviews/B001AO4OUC            21    0.00
# 4     https://www.amazon.com/product-reviews/B001DCJAJG            12  149.99
# ...                                                 ...           ...     ...
# 1435  https://www.amazon.com/product-reviews/B07ZPKZSSC             1  949.00
# 1436  https://www.amazon.com/product-reviews/B07ZQSGP53             3  150.96
# 1437  https://www.amazon.com/product-reviews/B081H6STQQ            70  948.00
# 1438  https://www.amazon.com/product-reviews/B081TJFVCJ             1  478.97
# 1439  https://www.amazon.com/product-reviews/B0825BB7SG             1  139.00
#
#       originalPrice
# 0              0.00
# 1              0.00
# 2              0.00
# 3              0.00
# 4              0.00
# ...             ...
# 1435           0.00
# 1436           0.00
# 1437           0.00
# 1438           0.00
# 1439         139.26
#
# [1440 rows x 11 columns]

# %% [markdown]
# ## Transform - Cleaning of data

# %%
mobile_df.shape
# Out:
# (1440, 11)

# %%
#Check if null values exists
mobile_df.isna().sum()
# Out:
# _id              0
# asin             0
# brand            8
# title            0
# url              0
# image            0
# rating           0
# reviewUrl        0
# totalReviews     0
# price            0
# originalPrice    0
# dtype: int64

# %%
# Drop records having values null
mobile_df = mobile_df.dropna()

# %%
mobile_df.isna().sum()
# Out:
# _id              0
# asin             0
# brand            0
# title            0
# url              0
# image            0
# rating           0
# reviewUrl        0
# totalReviews     0
# price            0
# originalPrice    0
# dtype: int64

# %%
# Dropped columns 'reviewUrl','url','image' for cleaning data as per requirement
mobile_df = mobile_df.drop(['reviewUrl','url','image'],axis=1)

# %%
mobile_df
# Out:
#                            _id        asin     brand  \
# 1     644b208e025de930036751eb  B0009N5L7K  Motorola
# 2     644b208e025de930036751ec  B000SKTZ0S  Motorola
# 3     644b208e025de930036751ed  B001AO4OUC  Motorola
# 4     644b208e025de930036751ee  B001DCJAJG  Motorola
# 5     644b208e025de930036751ef  B001GQ3DJM     Nokia
# ...                        ...         ...       ...
# 1435  64502fc0b43a387639203fa4  B07ZPKZSSC     Apple
# 1436  64502fc0b43a387639203fa5  B07ZQSGP53    Xiaomi
# 1437  64502fc0b43a387639203fa6  B081H6STQQ      Sony
# 1438  64502fc0b43a387639203fa7  B081TJFVCJ     Apple
# 1439  64502fc0b43a387639203fa8  B0825BB7SG   Samsung
#
#                                                   title  rating  totalReviews  \
# 1                                   Motorola I265 phone     3.0             7
# 2     MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...     2.7            22
# 3                 Motorola i335 Cell Phone Boost Mobile     3.3            21
# 4         Motorola V365 no contract cellular phone AT&T     3.1            12
# 5                     Nokia 1680 Black Phone (T-Mobile)     2.7             3
# ...                                                 ...     ...           ...
# 1435  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...     1.0             1
# 1436  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...     4.6             3
# 1437  Sony Xperia 1 Unlocked Smartphone and WH1000XM...     4.5            70
# 1438  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...     5.0             1
# 1439  Straight Talk Samsung Galaxy A10e Smartphone 5...     5.0             1
#
#        price  originalPrice
# 1      49.95           0.00
# 2      99.99           0.00
# 3       0.00           0.00
# 4     149.99           0.00
# 5       0.00           0.00
# ...      ...            ...
# 1435  949.00           0.00
# 1436  150.96           0.00
# 1437  948.00           0.00
# 1438  478.97           0.00
# 1439  139.00         139.26
#
# [1432 rows x 8 columns]

# %%
# Coverting price in dollar into rupees
exchange_rate = 80
mobile_df['Price'] = mobile_df['price'] * exchange_rate
mobile_df['original_price'] = mobile_df['originalPrice']*exchange_rate

# %%
mobile_df
# Out:
#                            _id        asin     brand  \
# 1     644b208e025de930036751eb  B0009N5L7K  Motorola
# 2     644b208e025de930036751ec  B000SKTZ0S  Motorola
# 3     644b208e025de930036751ed  B001AO4OUC  Motorola
# 4     644b208e025de930036751ee  B001DCJAJG  Motorola
# 5     644b208e025de930036751ef  B001GQ3DJM     Nokia
# ...                        ...         ...       ...
# 1435  64502fc0b43a387639203fa4  B07ZPKZSSC     Apple
# 1436  64502fc0b43a387639203fa5  B07ZQSGP53    Xiaomi
# 1437  64502fc0b43a387639203fa6  B081H6STQQ      Sony
# 1438  64502fc0b43a387639203fa7  B081TJFVCJ     Apple
# 1439  64502fc0b43a387639203fa8  B0825BB7SG   Samsung
#
#                                                   title  rating  totalReviews  \
# 1                                   Motorola I265 phone     3.0             7
# 2     MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...     2.7            22
# 3                 Motorola i335 Cell Phone Boost Mobile     3.3            21
# 4         Motorola V365 no contract cellular phone AT&T     3.1            12
# 5                     Nokia 1680 Black Phone (T-Mobile)     2.7             3
# ...                                                 ...     ...           ...
# 1435  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...     1.0             1
# 1436  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...     4.6             3
# 1437  Sony Xperia 1 Unlocked Smartphone and WH1000XM...     4.5            70
# 1438  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...     5.0             1
# 1439  Straight Talk Samsung Galaxy A10e Smartphone 5...     5.0             1
#
#        price  originalPrice    Price  original_price
# 1      49.95           0.00   3996.0             0.0
# 2      99.99           0.00   7999.2             0.0
# 3       0.00           0.00      0.0             0.0
# 4     149.99           0.00  11999.2             0.0
# 5       0.00           0.00      0.0             0.0
# ...      ...            ...      ...             ...
# 1435  949.00           0.00  75920.0             0.0
# 1436  150.96           0.00  12076.8             0.0
# 1437  948.00           0.00  75840.0             0.0
# 1438  478.97           0.00  38317.6             0.0
# 1439  139.00         139.26  11120.0         11140.8
#
# [1432 rows x 10 columns]

# %%
# Dropping columns which was in dollar currency
mobile_df = mobile_df.drop(['price','originalPrice'],axis=1)

# %%
mobile_df
# Out:
#                            _id        asin     brand  \
# 1     644b208e025de930036751eb  B0009N5L7K  Motorola
# 2     644b208e025de930036751ec  B000SKTZ0S  Motorola
# 3     644b208e025de930036751ed  B001AO4OUC  Motorola
# 4     644b208e025de930036751ee  B001DCJAJG  Motorola
# 5     644b208e025de930036751ef  B001GQ3DJM     Nokia
# ...                        ...         ...       ...
# 1435  64502fc0b43a387639203fa4  B07ZPKZSSC     Apple
# 1436  64502fc0b43a387639203fa5  B07ZQSGP53    Xiaomi
# 1437  64502fc0b43a387639203fa6  B081H6STQQ      Sony
# 1438  64502fc0b43a387639203fa7  B081TJFVCJ     Apple
# 1439  64502fc0b43a387639203fa8  B0825BB7SG   Samsung
#
#                                                   title  rating  totalReviews  \
# 1                                   Motorola I265 phone     3.0             7
# 2     MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...     2.7            22
# 3                 Motorola i335 Cell Phone Boost Mobile     3.3            21
# 4         Motorola V365 no contract cellular phone AT&T     3.1            12
# 5                     Nokia 1680 Black Phone (T-Mobile)     2.7             3
# ...                                                 ...     ...           ...
# 1435  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...     1.0             1
# 1436  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...     4.6             3
# 1437  Sony Xperia 1 Unlocked Smartphone and WH1000XM...     4.5            70
# 1438  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...     5.0             1
# 1439  Straight Talk Samsung Galaxy A10e Smartphone 5...     5.0             1
#
#         Price  original_price
# 1      3996.0             0.0
# 2      7999.2             0.0
# 3         0.0             0.0
# 4     11999.2             0.0
# 5         0.0             0.0
# ...       ...             ...
# 1435  75920.0             0.0
# 1436  12076.8             0.0
# 1437  75840.0             0.0
# 1438  38317.6             0.0
# 1439  11120.0         11140.8
#
# [1432 rows x 8 columns]

# %% [markdown]
# # Load - Loading the cleaned data in mysql (Structured)

# %%
# load data to mysql table
mobile_df.to_sql(name='mobile_tb', con=engine, if_exists='replace', index=False)
# Out:
# 1432

# %%
# check the table
pd.read_sql('SHOW TABLES', engine)
# Out:
#   Tables_in_dap_project
# 0             amazon_tb
# 1           flipkart_tb
# 2             mobile_tb
