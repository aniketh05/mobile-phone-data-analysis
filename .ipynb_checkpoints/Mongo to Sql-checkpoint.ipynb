# %%
# pip install pandas mysql-connector-python

# %% [markdown]
# # ETL Process for Amazon Dataset

# %% [markdown]
# ## Extract - Extracting data from MongoDB(Semi-structured)

# %%
#Import neccessary libraries
import pymongo
import pandas as pd
import mysql.connector

# %%
#connect to MongoDB server
client = pymongo.MongoClient('mongodb://dap:dap@localhost:27017/?authMechanism=DEFAULT', serverSelectionTimeoutMS=50000)
database_name = 'DAP_Project'
collection_list = client.list_database_names()
collection_list
# Out:
# ['DAP_Project', 'admin', 'config', 'local']

# %%
# Check if database name exist - 
    #if yes - then it will access collection and load data in Amazon_data
    #if no - it will raise ValueError
    
if database_name in collection_list:
    db = client[database_name]
    Amazon_collection = db['Amazon']
    Amazon_data = Amazon_collection.find()
else:
    raise ValueError(f"Database {database_name} not found in the collection list")

# %%
#convert data into pandas DataFrame
amazon_df = pd.DataFrame(list(Amazon_data))

# %%
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   ₹8,499
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  ₹79,999
# 2    OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 8GB...  ₹19,999
# 3    Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   ₹8,499
# 4    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 8GB RA...  ₹21,999
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...   ₹7,480
# 530  Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...   ₹8,499
# 531  realme narzo 50 (Speed Black, 6GB RAM+128GB St...  ₹15,499
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  ₹18,999
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  ₹18,999
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %% [markdown]
# ## Transform - Cleaning of data

# %%
#checking record for reviews column for 0th index
amazon_df['reviews'][0]
# Out:
# '3,886 ratings'

# %%
# Dataframe contains blank spaces so replace blank with none.

amazon_df['price'] = amazon_df['price'].replace('', None)
amazon_df['reviews'] = amazon_df['reviews'].replace('', None)
amazon_df['availability'] = amazon_df['availability'].replace('', None)

# %%
# Check if null values exists
amazon_df.isnull().sum()
# Out:
# _id              0
# title            0
# price            1
# rating           0
# reviews         22
# availability     2
# dtype: int64

# %%
amazon_df['price'] = amazon_df['price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2    OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 8GB...  19999.0
# 3    Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...   8499.0
# 4    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 8GB RA...  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...   7480.0
# 530  Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...   8499.0
# 531  realme narzo 50 (Speed Black, 6GB RAM+128GB St...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
amazon_df['title'] = amazon_df['title'].str.replace('(\d+GB) RAM.*(\d+GB|\d+TB) Storage', '')
# Out:
# C:\Users\Begena\AppData\Local\Temp\ipykernel_13044\3363329258.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_df['title'] = amazon_df['title'].str.replace('(\d+GB) RAM.*(\d+GB|\d+TB) Storage', '')

# %%
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
amazon_df = amazon_df.apply(lambda x: x.str.strip() if x.dtype == 'object' and x.name != '_id' else x)

# %%
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
amazon_df = amazon_df.reset_index(drop=True)

# %%
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
amazon_df['reviews'].fillna("0 ratings", inplace=True)

# %%
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
# Find most frequently occurring rating as average
frequency_rating = amazon_df['rating'].mode()[0]
frequency_rating
# Out:
# '4.1 out of 5 stars'

# %%
# Identifying the garbage rating and replacing it with average ration i.e. '4.5 out of 5 starts'
amazon_df['rating'] = amazon_df['rating'].replace('Previous page', frequency_rating)
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0
# ..                                                 ...      ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0
#
#                  rating          reviews availability
# 0    3.9 out of 5 stars    3,886 ratings     In stock
# 1    4.5 out of 5 stars      699 ratings     In stock
# 2    3.6 out of 5 stars       18 ratings     In stock
# 3    3.9 out of 5 stars    3,886 ratings     In stock
# 4    3.6 out of 5 stars       18 ratings     In stock
# ..                  ...              ...          ...
# 529  4.1 out of 5 stars  322,513 ratings     In stock
# 530  3.9 out of 5 stars    3,886 ratings     In stock
# 531  4.2 out of 5 stars   16,097 ratings     In stock
# 532  4.1 out of 5 stars      914 ratings     In stock
# 533  4.1 out of 5 stars      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
#Unique values for rating column
amazon_df['rating'].unique()
# Out:
# array(['3.9 out of 5 stars', '4.5 out of 5 stars', '3.6 out of 5 stars',
#        '4.1 out of 5 stars', '4.0 out of 5 stars', '4.3 out of 5 stars',
#        '4.4 out of 5 stars', '4.8 out of 5 stars', '4.2 out of 5 stars'],
#       dtype=object)

# %%
# Extracting the 1st 3 characters of rating column to get rid of repetative string 'out of 5 stars' numeric value
amazon_df['rating'] = amazon_df['rating'].apply(lambda x: float(str(x[:3]))) 
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  rating  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0     4.5
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0     3.6
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0     3.6
# ..                                                 ...      ...     ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0     4.1
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0     3.9
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0     4.2
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0     4.1
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0     4.1
#
#              reviews availability
# 0      3,886 ratings     In stock
# 1        699 ratings     In stock
# 2         18 ratings     In stock
# 3      3,886 ratings     In stock
# 4         18 ratings     In stock
# ..               ...          ...
# 529  322,513 ratings     In stock
# 530    3,886 ratings     In stock
# 531   16,097 ratings     In stock
# 532      914 ratings     In stock
# 533      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
#Convert reviews column in string format
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: str(x))
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  rating  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0     4.5
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0     3.6
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0     3.6
# ..                                                 ...      ...     ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0     4.1
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0     3.9
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0     4.2
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0     4.1
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0     4.1
#
#              reviews availability
# 0      3,886 ratings     In stock
# 1        699 ratings     In stock
# 2         18 ratings     In stock
# 3      3,886 ratings     In stock
# 4         18 ratings     In stock
# ..               ...          ...
# 529  322,513 ratings     In stock
# 530    3,886 ratings     In stock
# 531   16,097 ratings     In stock
# 532      914 ratings     In stock
# 533      914 ratings     In stock
#
# [534 rows x 6 columns]

# %%
# Delete ratings word and comma from reviews
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: x[:-7])
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: x.replace(",", ""))
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  rating  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0     4.5
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0     3.6
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0     3.6
# ..                                                 ...      ...     ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0     4.1
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0     3.9
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0     4.2
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0     4.1
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0     4.1
#
#      reviews availability
# 0      3886      In stock
# 1       699      In stock
# 2        18      In stock
# 3      3886      In stock
# 4        18      In stock
# ..       ...          ...
# 529  322513      In stock
# 530    3886      In stock
# 531   16097      In stock
# 532     914      In stock
# 533     914      In stock
#
# [534 rows x 6 columns]

# %%
#Covert reviws in int format
amazon_df['reviews'] = amazon_df['reviews'].apply(lambda x: int(x))
amazon_df
# Out:
#                           _id  \
# 0    644c3ccb499890cfbaf2a400
# 1    644c3ccb499890cfbaf2a401
# 2    644c3ccb499890cfbaf2a402
# 3    644c3ccb499890cfbaf2a403
# 4    644c3ccb499890cfbaf2a404
# ..                        ...
# 529  644c3ccb499890cfbaf2a611
# 530  644c3ccb499890cfbaf2a612
# 531  644c3ccb499890cfbaf2a613
# 532  644c3ccb499890cfbaf2a614
# 533  644c3ccb499890cfbaf2a615
#
#                                                  title    price  rating  \
# 0    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 1    Samsung Galaxy S23 5G (Phantom Black, 8GB, 256...  79999.0     4.5
# 2         OnePlus Nord CE 3 Lite 5G (Chromatic Gray, )  19999.0     3.6
# 3    Samsung Galaxy M04 Light Green,  | Upto 8GB RA...   8499.0     3.9
# 4            OnePlus Nord CE 3 Lite 5G (Pastel Lime, )  21999.0     3.6
# ..                                                 ...      ...     ...
# 529  Redmi 9A (Midnight Black ) | 2GHz Octa-core He...   7480.0     4.1
# 530  Samsung Galaxy M04 Dark Blue,  | Upto 8GB RAM ...   8499.0     3.9
# 531  realme narzo 50 (Speed Black, ) Helio G96 Proc...  15499.0     4.2
# 532  Oppo A78 5G (Glowing Black, 8GB RAM, 128 Stora...  18999.0     4.1
# 533  Oppo A78 5G (Glowing Blue, 8GB RAM, 128 Storag...  18999.0     4.1
#
#      reviews availability
# 0       3886     In stock
# 1        699     In stock
# 2         18     In stock
# 3       3886     In stock
# 4         18     In stock
# ..       ...          ...
# 529   322513     In stock
# 530     3886     In stock
# 531    16097     In stock
# 532      914     In stock
# 533      914     In stock
#
# [534 rows x 6 columns]

# %% [markdown]
# ## Load - Loading the cleaned data in mysql (Structured)

# %%
# Install pymysql
# pip install pymysql

# %%
# Import necessary libraries
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# create database connection string
db_connection_str = 'mysql+pymysql://root:root@localhost:3306/dap_project'

# create sqlalchemy engine
engine = create_engine(db_connection_str)

# create database if it doesn't exist
with engine.connect() as con:
    con.execute('CREATE DATABASE IF NOT EXISTS dap_project')

# switch to database
with engine.connect() as con:
    con.execute('USE dap_project')

# load data to mysql table
amazon_df.to_sql(name='amazon_tb', con=engine, if_exists='replace', index=False)
# Out:
# 534

# %%
# check the table
pd.read_sql('SHOW TABLES', engine)
# Out:
#   Tables_in_dap_project
# 0             amazon_tb

# %% [markdown]
# #  ETL Process for Flipkart Dataset

# %% [markdown]
# ## Extract - Extracting data from MongoDB(Semi-structured)

# %%
#connect to MongoDB server

#client = pymongo.MongoClient('mongodb://localhost:27017/', serverSelectionTimeoutMS=50000)
#database_name = 'DAP_Project'
#collection_list = client.list_database_names()
#collection_list

# %%
# Check if database name exist - 
    #if yes - then it will access collection and load data in Amazon_data
    #if no - it will raise ValueError
    
if database_name in collection_list:
    db = client[database_name]
    Flipkart_collection = db['Flipkart']
    Flipkart_data = Flipkart_collection.find()
else:
    raise ValueError(f"Database {database_name} not found in the collection list")

# %%
# Convert data into pandas DataFrame
flipkart_df =pd.DataFrame(list(Flipkart_data))

# %%
flipkart_df
# Out:
#                           _id  \
# 0    644c43f1499890cfbaf2a617
# 1    644c43f1499890cfbaf2a618
# 2    644c43f1499890cfbaf2a619
# 3    644c43f1499890cfbaf2a61a
# 4    644c43f1499890cfbaf2a61b
# ..                        ...
# 979  644c43f1499890cfbaf2a9ea
# 980  644c43f1499890cfbaf2a9eb
# 981  644c43f1499890cfbaf2a9ec
# 982  644c43f1499890cfbaf2a9ed
# 983  644c43f1499890cfbaf2a9ee
#
#                                                  title    price rating  \
# 0    SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   ₹9,699    4.4
# 1    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   ₹9,699    4.4
# 2    SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   ₹9,699    4.4
# 3    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)  (...  ₹10,699    4.4
# 4             POCO C50 (Royal Blue, 32 GB)  (2 GB RAM)   ₹6,499    4.3
# ..                                                 ...      ...    ...
# 979       realme C31 (Light Silver, 32 GB)  (3 GB RAM)   ₹9,299    4.5
# 980               itel iPower 430 Triple sim  (Orange)   ₹1,499    3.9
# 981                             Kechaoda K28  (Coffee)   ₹1,399    4.1
# 982                               LAVA A7  (Sea Green)   ₹1,799    4.2
# 983        OPPO A76 (Glowing Blue, 128 GB)  (6 GB RAM)  ₹16,490    4.3
#
#     camera_rating        rating_count
# 0                  1,39,579 Ratings &
# 1                  1,39,579 Ratings &
# 2                  1,39,579 Ratings &
# 3                  1,39,579 Ratings &
# 4                    18,639 Ratings &
# ..            ...                 ...
# 979                  47,541 Ratings &
# 980                      53 Ratings &
# 981                   2,922 Ratings &
# 982                   6,984 Ratings &
# 983                     404 Ratings &
#
# [984 rows x 6 columns]

# %% [markdown]
# ## Transform - Cleaning of data

# %%
#Chcek null values
flipkart_df.isnull().sum()
# Out:
# _id              0
# title            0
# price            0
# rating           0
# camera_rating    0
# rating_count     0
# dtype: int64

# %%
# Dataframe contains blank spaces so replace blank with none.
flipkart_df['price'] = flipkart_df['price'].replace('', None)
flipkart_df['rating'] = flipkart_df['rating'].replace('', None)
flipkart_df['camera_rating'] = flipkart_df['camera_rating'].replace('', None)
flipkart_df['rating_count'] = flipkart_df['rating_count'].replace('', None)

# %%
flipkart_df.isnull().sum()
# Out:
# _id                0
# title              0
# price              0
# rating            32
# camera_rating    984
# rating_count      32
# dtype: int64

# %%
#drop column camera_rating as it does not have any record.
flipkart_df = flipkart_df.drop(["camera_rating"], axis=1)

# %%
flipkart_df
# Out:
#                           _id  \
# 0    644c43f1499890cfbaf2a617
# 1    644c43f1499890cfbaf2a618
# 2    644c43f1499890cfbaf2a619
# 3    644c43f1499890cfbaf2a61a
# 4    644c43f1499890cfbaf2a61b
# ..                        ...
# 979  644c43f1499890cfbaf2a9ea
# 980  644c43f1499890cfbaf2a9eb
# 981  644c43f1499890cfbaf2a9ec
# 982  644c43f1499890cfbaf2a9ed
# 983  644c43f1499890cfbaf2a9ee
#
#                                                  title    price rating  \
# 0    SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   ₹9,699    4.4
# 1    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   ₹9,699    4.4
# 2    SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   ₹9,699    4.4
# 3    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)  (...  ₹10,699    4.4
# 4             POCO C50 (Royal Blue, 32 GB)  (2 GB RAM)   ₹6,499    4.3
# ..                                                 ...      ...    ...
# 979       realme C31 (Light Silver, 32 GB)  (3 GB RAM)   ₹9,299    4.5
# 980               itel iPower 430 Triple sim  (Orange)   ₹1,499    3.9
# 981                             Kechaoda K28  (Coffee)   ₹1,399    4.1
# 982                               LAVA A7  (Sea Green)   ₹1,799    4.2
# 983        OPPO A76 (Glowing Blue, 128 GB)  (6 GB RAM)  ₹16,490    4.3
#
#            rating_count
# 0    1,39,579 Ratings &
# 1    1,39,579 Ratings &
# 2    1,39,579 Ratings &
# 3    1,39,579 Ratings &
# 4      18,639 Ratings &
# ..                  ...
# 979    47,541 Ratings &
# 980        53 Ratings &
# 981     2,922 Ratings &
# 982     6,984 Ratings &
# 983       404 Ratings &
#
# [984 rows x 5 columns]

# %%
flipkart_df.isnull().sum()
# Out:
# _id              0
# title            0
# price            0
# rating          32
# rating_count    32
# dtype: int64

# %%
# Fill null values with 0
flipkart_df.fillna(0, inplace=True)

# %%
flipkart_df.isnull().sum()
# Out:
# _id             0
# title           0
# price           0
# rating          0
# rating_count    0
# dtype: int64

# %%
#Cleaning rating_count colum
flipkart_df["rating_count"] = flipkart_df["rating_count"].str.rstrip('Ratings &')

# %%
flipkart_df
# Out:
#                           _id  \
# 0    644c43f1499890cfbaf2a617
# 1    644c43f1499890cfbaf2a618
# 2    644c43f1499890cfbaf2a619
# 3    644c43f1499890cfbaf2a61a
# 4    644c43f1499890cfbaf2a61b
# ..                        ...
# 979  644c43f1499890cfbaf2a9ea
# 980  644c43f1499890cfbaf2a9eb
# 981  644c43f1499890cfbaf2a9ec
# 982  644c43f1499890cfbaf2a9ed
# 983  644c43f1499890cfbaf2a9ee
#
#                                                  title    price rating  \
# 0    SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   ₹9,699    4.4
# 1    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   ₹9,699    4.4
# 2    SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   ₹9,699    4.4
# 3    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)  (...  ₹10,699    4.4
# 4             POCO C50 (Royal Blue, 32 GB)  (2 GB RAM)   ₹6,499    4.3
# ..                                                 ...      ...    ...
# 979       realme C31 (Light Silver, 32 GB)  (3 GB RAM)   ₹9,299    4.5
# 980               itel iPower 430 Triple sim  (Orange)   ₹1,499    3.9
# 981                             Kechaoda K28  (Coffee)   ₹1,399    4.1
# 982                               LAVA A7  (Sea Green)   ₹1,799    4.2
# 983        OPPO A76 (Glowing Blue, 128 GB)  (6 GB RAM)  ₹16,490    4.3
#
#     rating_count
# 0       1,39,579
# 1       1,39,579
# 2       1,39,579
# 3       1,39,579
# 4         18,639
# ..           ...
# 979       47,541
# 980           53
# 981        2,922
# 982        6,984
# 983          404
#
# [984 rows x 5 columns]

# %%
flipkart_df['rating_count'] = flipkart_df['rating_count'].str.replace(',','').astype(float)

# %%
flipkart_df
# Out:
#                           _id  \
# 0    644c43f1499890cfbaf2a617
# 1    644c43f1499890cfbaf2a618
# 2    644c43f1499890cfbaf2a619
# 3    644c43f1499890cfbaf2a61a
# 4    644c43f1499890cfbaf2a61b
# ..                        ...
# 979  644c43f1499890cfbaf2a9ea
# 980  644c43f1499890cfbaf2a9eb
# 981  644c43f1499890cfbaf2a9ec
# 982  644c43f1499890cfbaf2a9ed
# 983  644c43f1499890cfbaf2a9ee
#
#                                                  title    price rating  \
# 0    SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   9699.0    4.4
# 1    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   9699.0    4.4
# 2    SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   9699.0    4.4
# 3    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)  (...  10699.0    4.4
# 4             POCO C50 (Royal Blue, 32 GB)  (2 GB RAM)   6499.0    4.3
# ..                                                 ...      ...    ...
# 979       realme C31 (Light Silver, 32 GB)  (3 GB RAM)   9299.0    4.5
# 980               itel iPower 430 Triple sim  (Orange)   1499.0    3.9
# 981                             Kechaoda K28  (Coffee)   1399.0    4.1
# 982                               LAVA A7  (Sea Green)   1799.0    4.2
# 983        OPPO A76 (Glowing Blue, 128 GB)  (6 GB RAM)  16490.0    4.3
#
#      rating_count
# 0        139579.0
# 1        139579.0
# 2        139579.0
# 3        139579.0
# 4         18639.0
# ..            ...
# 979       47541.0
# 980          53.0
# 981        2922.0
# 982        6984.0
# 983         404.0
#
# [984 rows x 5 columns]

# %%
flipkart_df['price'] = flipkart_df['price'].str.replace('₹','').str.replace(',','').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13044\3676756399.py in <module>
# ----> 1 flipkart_df['price'] = flipkart_df['price'].str.replace('₹','').str.replace(',','').astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!

# %%
flipkart_df
# Out:
#                           _id  \
# 0    644c43f1499890cfbaf2a617
# 1    644c43f1499890cfbaf2a618
# 2    644c43f1499890cfbaf2a619
# 3    644c43f1499890cfbaf2a61a
# 4    644c43f1499890cfbaf2a61b
# ..                        ...
# 979  644c43f1499890cfbaf2a9ea
# 980  644c43f1499890cfbaf2a9eb
# 981  644c43f1499890cfbaf2a9ec
# 982  644c43f1499890cfbaf2a9ed
# 983  644c43f1499890cfbaf2a9ee
#
#                                                  title    price rating  \
# 0    SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   9699.0    4.4
# 1    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   9699.0    4.4
# 2    SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   9699.0    4.4
# 3    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)  (...  10699.0    4.4
# 4             POCO C50 (Royal Blue, 32 GB)  (2 GB RAM)   6499.0    4.3
# ..                                                 ...      ...    ...
# 979       realme C31 (Light Silver, 32 GB)  (3 GB RAM)   9299.0    4.5
# 980               itel iPower 430 Triple sim  (Orange)   1499.0    3.9
# 981                             Kechaoda K28  (Coffee)   1399.0    4.1
# 982                               LAVA A7  (Sea Green)   1799.0    4.2
# 983        OPPO A76 (Glowing Blue, 128 GB)  (6 GB RAM)  16490.0    4.3
#
#      rating_count
# 0        139579.0
# 1        139579.0
# 2        139579.0
# 3        139579.0
# 4         18639.0
# ..            ...
# 979       47541.0
# 980          53.0
# 981        2922.0
# 982        6984.0
# 983         404.0
#
# [984 rows x 5 columns]

# %% [markdown]
# ## Load - Loading the cleaned data in mysql (Structured)

# %%
import pymysql
import pandas
from sqlalchemy import create_engine

# %%
# load data to mysql table
flipkart_df.to_sql(name='flipkart_tb', con=engine, if_exists='replace', index=False)
# Out:
# 984

# %%
# check the table
pd.read_sql('SHOW TABLES', engine)
# Out:
#   Tables_in_dap_project
# 0             amazon_tb
# 1           flipkart_tb

# %% [markdown]
# # ETL process for other Mobile_data

# %% [markdown]
# ## Extract - Extracting data from MongoDB(Semi-structured)

# %%
##client = pymongo.MongoClient('mongodb://localhost:27017/', serverSelectionTimeoutMS=50000)
##database_name = 'DAP_Project'
##collection_list = client.list_database_names()
##collection_list

# %%
# Check if database name exist - 
    #if yes - then it will access collection and load data in Amazon_data
    #if no - it will raise ValueError
    
if database_name in collection_list:
    db = client[database_name]
    Mobile_collection = db['Mobile_data']
    Mobile_data = Mobile_collection.find()
else:
    raise ValueError(f"Database {database_name} not found in the collection list")

# %%
##convert data into pandas DataFrame
mobile_df = pd.DataFrame(list(Mobile_data))

# %%
mobile_df
# Out:
#                           _id        asin     brand  \
# 0    644c43f1499890cfbaf2a9f0  B0000SX2UC       NaN
# 1    644c43f1499890cfbaf2a9f1  B0009N5L7K  Motorola
# 2    644c43f1499890cfbaf2a9f2  B000SKTZ0S  Motorola
# 3    644c43f1499890cfbaf2a9f3  B001AO4OUC  Motorola
# 4    644c43f1499890cfbaf2a9f4  B001DCJAJG  Motorola
# ..                        ...         ...       ...
# 715  644c43f1499890cfbaf2acbb  B07ZPKZSSC     Apple
# 716  644c43f1499890cfbaf2acbc  B07ZQSGP53    Xiaomi
# 717  644c43f1499890cfbaf2acbd  B081H6STQQ      Sony
# 718  644c43f1499890cfbaf2acbe  B081TJFVCJ     Apple
# 719  644c43f1499890cfbaf2acbf  B0825BB7SG   Samsung
#
#                                                  title  \
# 0    Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1                                  Motorola I265 phone
# 2    MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3                Motorola i335 Cell Phone Boost Mobile
# 4        Motorola V365 no contract cellular phone AT&T
# ..                                                 ...
# 715  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...
# 716  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...
# 717  Sony Xperia 1 Unlocked Smartphone and WH1000XM...
# 718  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...
# 719  Straight Talk Samsung Galaxy A10e Smartphone 5...
#
#                                                    url  \
# 0    https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1    https://www.amazon.com/Motorola-i265-I265-phon...
# 2    https://www.amazon.com/MOTOROLA-C168i-CINGULAR...
# 3    https://www.amazon.com/Motorola-i335-Phone-Boo...
# 4    https://www.amazon.com/Motorola-V365-contract-...
# ..                                                 ...
# 715  https://www.amazon.com/Apple-iPhone-64GB-Fully...
# 716  https://www.amazon.com/Xiaomi-Display-Snapdrag...
# 717  https://www.amazon.com/Sony-Smartphone-WH1000X...
# 718  https://www.amazon.com/Apple-iPhone-64GB-Gray-...
# 719  https://www.amazon.com/Straight-Samsung-Galaxy...
#
#                                                  image  rating  \
# 0    https://m.media-amazon.com/images/I/2143EBQ210...     3.0
# 1    https://m.media-amazon.com/images/I/419WBAVDAR...     3.0
# 2    https://m.media-amazon.com/images/I/71b+q3ydkI...     2.7
# 3    https://m.media-amazon.com/images/I/710UO8gdT+...     3.3
# 4    https://m.media-amazon.com/images/I/61LYNCVrrK...     3.1
# ..                                                 ...     ...
# 715  https://m.media-amazon.com/images/I/41wDuEW9iZ...     1.0
# 716  https://m.media-amazon.com/images/I/41foh4FKHE...     4.6
# 717  https://m.media-amazon.com/images/I/51zZTAXZTP...     4.5
# 718  https://m.media-amazon.com/images/I/71yMgOenT5...     5.0
# 719  https://m.media-amazon.com/images/I/81+3SWSAhD...     5.0
#
#                                              reviewUrl  totalReviews   price  \
# 0    https://www.amazon.com/product-reviews/B0000SX2UC            14    0.00
# 1    https://www.amazon.com/product-reviews/B0009N5L7K             7   49.95
# 2    https://www.amazon.com/product-reviews/B000SKTZ0S            22   99.99
# 3    https://www.amazon.com/product-reviews/B001AO4OUC            21    0.00
# 4    https://www.amazon.com/product-reviews/B001DCJAJG            12  149.99
# ..                                                 ...           ...     ...
# 715  https://www.amazon.com/product-reviews/B07ZPKZSSC             1  949.00
# 716  https://www.amazon.com/product-reviews/B07ZQSGP53             3  150.96
# 717  https://www.amazon.com/product-reviews/B081H6STQQ            70  948.00
# 718  https://www.amazon.com/product-reviews/B081TJFVCJ             1  478.97
# 719  https://www.amazon.com/product-reviews/B0825BB7SG             1  139.00
#
#      originalPrice
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
# ..             ...
# 715           0.00
# 716           0.00
# 717           0.00
# 718           0.00
# 719         139.26
#
# [720 rows x 11 columns]

# %% [markdown]
# ## Transform - Cleaning of data

# %%
#Check if null values exists
mobile_df.isna().sum()
# Out:
# _id              0
# asin             0
# brand            4
# title            0
# url              0
# image            0
# rating           0
# reviewUrl        0
# totalReviews     0
# price            0
# originalPrice    0
# dtype: int64

# %%
# Drop records having values null
mobile_df = mobile_df.dropna()

# %%
mobile_df.isna().sum()
# Out:
# _id              0
# asin             0
# brand            0
# title            0
# url              0
# image            0
# rating           0
# reviewUrl        0
# totalReviews     0
# price            0
# originalPrice    0
# dtype: int64

# %%
# Dropped columns 'reviewUrl','url','image' for cleaning data as per requirement
mobile_df = mobile_df.drop(['reviewUrl','url','image'],axis=1)

# %%
mobile_df
# Out:
#                           _id        asin     brand  \
# 1    644c43f1499890cfbaf2a9f1  B0009N5L7K  Motorola
# 2    644c43f1499890cfbaf2a9f2  B000SKTZ0S  Motorola
# 3    644c43f1499890cfbaf2a9f3  B001AO4OUC  Motorola
# 4    644c43f1499890cfbaf2a9f4  B001DCJAJG  Motorola
# 5    644c43f1499890cfbaf2a9f5  B001GQ3DJM     Nokia
# ..                        ...         ...       ...
# 715  644c43f1499890cfbaf2acbb  B07ZPKZSSC     Apple
# 716  644c43f1499890cfbaf2acbc  B07ZQSGP53    Xiaomi
# 717  644c43f1499890cfbaf2acbd  B081H6STQQ      Sony
# 718  644c43f1499890cfbaf2acbe  B081TJFVCJ     Apple
# 719  644c43f1499890cfbaf2acbf  B0825BB7SG   Samsung
#
#                                                  title  rating  totalReviews  \
# 1                                  Motorola I265 phone     3.0             7
# 2    MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...     2.7            22
# 3                Motorola i335 Cell Phone Boost Mobile     3.3            21
# 4        Motorola V365 no contract cellular phone AT&T     3.1            12
# 5                    Nokia 1680 Black Phone (T-Mobile)     2.7             3
# ..                                                 ...     ...           ...
# 715  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...     1.0             1
# 716  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...     4.6             3
# 717  Sony Xperia 1 Unlocked Smartphone and WH1000XM...     4.5            70
# 718  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...     5.0             1
# 719  Straight Talk Samsung Galaxy A10e Smartphone 5...     5.0             1
#
#       price  originalPrice
# 1     49.95           0.00
# 2     99.99           0.00
# 3      0.00           0.00
# 4    149.99           0.00
# 5      0.00           0.00
# ..      ...            ...
# 715  949.00           0.00
# 716  150.96           0.00
# 717  948.00           0.00
# 718  478.97           0.00
# 719  139.00         139.26
#
# [716 rows x 8 columns]

# %%
# Coverting price in dollar into rupees
exchange_rate = 80
mobile_df['Price'] = mobile_df['price'] * exchange_rate
mobile_df['original_price'] = mobile_df['originalPrice']*exchange_rate

# %%
mobile_df
# Out:
#                           _id        asin     brand  \
# 1    644c43f1499890cfbaf2a9f1  B0009N5L7K  Motorola
# 2    644c43f1499890cfbaf2a9f2  B000SKTZ0S  Motorola
# 3    644c43f1499890cfbaf2a9f3  B001AO4OUC  Motorola
# 4    644c43f1499890cfbaf2a9f4  B001DCJAJG  Motorola
# 5    644c43f1499890cfbaf2a9f5  B001GQ3DJM     Nokia
# ..                        ...         ...       ...
# 715  644c43f1499890cfbaf2acbb  B07ZPKZSSC     Apple
# 716  644c43f1499890cfbaf2acbc  B07ZQSGP53    Xiaomi
# 717  644c43f1499890cfbaf2acbd  B081H6STQQ      Sony
# 718  644c43f1499890cfbaf2acbe  B081TJFVCJ     Apple
# 719  644c43f1499890cfbaf2acbf  B0825BB7SG   Samsung
#
#                                                  title  rating  totalReviews  \
# 1                                  Motorola I265 phone     3.0             7
# 2    MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...     2.7            22
# 3                Motorola i335 Cell Phone Boost Mobile     3.3            21
# 4        Motorola V365 no contract cellular phone AT&T     3.1            12
# 5                    Nokia 1680 Black Phone (T-Mobile)     2.7             3
# ..                                                 ...     ...           ...
# 715  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...     1.0             1
# 716  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...     4.6             3
# 717  Sony Xperia 1 Unlocked Smartphone and WH1000XM...     4.5            70
# 718  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...     5.0             1
# 719  Straight Talk Samsung Galaxy A10e Smartphone 5...     5.0             1
#
#       price  originalPrice    Price  original_price
# 1     49.95           0.00   3996.0             0.0
# 2     99.99           0.00   7999.2             0.0
# 3      0.00           0.00      0.0             0.0
# 4    149.99           0.00  11999.2             0.0
# 5      0.00           0.00      0.0             0.0
# ..      ...            ...      ...             ...
# 715  949.00           0.00  75920.0             0.0
# 716  150.96           0.00  12076.8             0.0
# 717  948.00           0.00  75840.0             0.0
# 718  478.97           0.00  38317.6             0.0
# 719  139.00         139.26  11120.0         11140.8
#
# [716 rows x 10 columns]

# %%
# Dropping columns which was in dollar currency
mobile_df = mobile_df.drop(['price','originalPrice'],axis=1)

# %%
mobile_df
# Out:
#                           _id        asin     brand  \
# 1    644c43f1499890cfbaf2a9f1  B0009N5L7K  Motorola
# 2    644c43f1499890cfbaf2a9f2  B000SKTZ0S  Motorola
# 3    644c43f1499890cfbaf2a9f3  B001AO4OUC  Motorola
# 4    644c43f1499890cfbaf2a9f4  B001DCJAJG  Motorola
# 5    644c43f1499890cfbaf2a9f5  B001GQ3DJM     Nokia
# ..                        ...         ...       ...
# 715  644c43f1499890cfbaf2acbb  B07ZPKZSSC     Apple
# 716  644c43f1499890cfbaf2acbc  B07ZQSGP53    Xiaomi
# 717  644c43f1499890cfbaf2acbd  B081H6STQQ      Sony
# 718  644c43f1499890cfbaf2acbe  B081TJFVCJ     Apple
# 719  644c43f1499890cfbaf2acbf  B0825BB7SG   Samsung
#
#                                                  title  rating  totalReviews  \
# 1                                  Motorola I265 phone     3.0             7
# 2    MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...     2.7            22
# 3                Motorola i335 Cell Phone Boost Mobile     3.3            21
# 4        Motorola V365 no contract cellular phone AT&T     3.1            12
# 5                    Nokia 1680 Black Phone (T-Mobile)     2.7             3
# ..                                                 ...     ...           ...
# 715  Apple iPhone 11 Pro, 64GB, Fully Unlocked - Sp...     1.0             1
# 716  Xiaomi Redmi Note 8, 32GB/3GB RAM 6.3" FHD+ Di...     4.6             3
# 717  Sony Xperia 1 Unlocked Smartphone and WH1000XM...     4.5            70
# 718  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...     5.0             1
# 719  Straight Talk Samsung Galaxy A10e Smartphone 5...     5.0             1
#
#        Price  original_price
# 1     3996.0             0.0
# 2     7999.2             0.0
# 3        0.0             0.0
# 4    11999.2             0.0
# 5        0.0             0.0
# ..       ...             ...
# 715  75920.0             0.0
# 716  12076.8             0.0
# 717  75840.0             0.0
# 718  38317.6             0.0
# 719  11120.0         11140.8
#
# [716 rows x 8 columns]

# %% [markdown]
# # Load - Loading the cleaned data in mysql (Structured)

# %%
# load data to mysql table
flipkart_df.to_sql(name='flipkart_tb', con=engine, if_exists='replace', index=False)
# Out:
# 984

# %%
# check the table
pd.read_sql('SHOW TABLES', engine)
# Out:
#   Tables_in_dap_project
# 0             amazon_tb
# 1           flipkart_tb
# 2             mobile_tb
